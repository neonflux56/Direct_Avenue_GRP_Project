# %%
import calendar
import os
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import datetime
from dateutil import parser

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.utils import shuffle

from xgboost import XGBRegressor, DMatrix

import warnings

warnings.filterwarnings("ignore")

sns.set(rc={"figure.figsize": (11.7, 8.27)})

# %% [raw]
# # files = [f for f in os.listdir() if f.endswith('xlsx')]
# # dat = pd.concat([pd.read_excel(f) for f in files])
#
# dat = pd.read_csv('../Data/data.csv.zip', compression='zip')
# os.chdir('/home/jovyan/git/Direct_Avenue_GRP_Project/')

# %% [raw]
# dat = dat.rename(columns={'Impression(000)': 'Impressions'})

# %% [raw]
# dat['Date Aired'] = pd.to_datetime(dat['Date Aired'], format='%Y-%m-%d')
# dat['Time Aired'] = pd.to_datetime(dat['Time Aired'], format='%H:%M:%S').dt.time

# %% [raw]
# def daypart(row):
#     if row['Time Aired'].hour >= 0 and row['Time Aired'].hour < 2:
#         return('Late Night')
#     elif row['Time Aired'].hour >= 2 and row['Time Aired'].hour < 6:
#         return('Overnight')
#     elif row['Time Aired'].hour >= 6 and row['Time Aired'].hour < 9:
#             return('Morning')
#     elif row['Time Aired'].hour >= 9 and row['Time Aired'].hour < 16:
#         return('Daytime')
#     elif row['Time Aired'].hour >= 16 and row['Time Aired'].hour < 19:
#         return('Early Fringe')
#     elif row['Time Aired'].hour >= 19 and row['Time Aired'].hour < 22:
#         return('Primetime')
#     else:
#         return('Late Fringe')
#
# dat['DOW'] = dat['Date Aired'].dt.day_name()
# dat['daypart'] = dat.apply(daypart, axis=1)

# %% [raw]
# dat.to_csv('cleaned_data.csv')

# %% [markdown]
# ### Load file here

# %%
dat = pd.read_csv("../cleaned_data.csv")

# %% [markdown]
# .

# %%
dat = dat.loc[:, "Access":]

# %%
dat
# Out:
#        Access  DMA  Date Aired Estimate    GRP  Impressions  Length  \
# 0        30GD  900  2019-02-25     Q119  0.000          0.0      30
# 1        30GD  900  2019-02-25     Q119  0.000          0.0      30
# 2        30SR  900  2019-02-25     Q119  0.000          0.0      30
# 3        30BP  900  2019-02-25     Q119  0.000          0.0      30
# 4        30BP  900  2019-02-25     Q119  0.000          0.0      30
# ...       ...  ...         ...      ...    ...          ...     ...
# 683352   30TN  900  2019-01-27     Q119  0.000          NaN      30
# 683353   30DP  900  2019-01-27     Q119  0.016          NaN      30
# 683354   30TN  900  2019-01-27     Q119  0.000          NaN      30
# 683355   30TN  900  2019-01-27     Q119  0.016          NaN      30
# 683356   30TN  900  2019-01-27     Q119  0.000          NaN      30
#
#                                 Market Media  Spot Cost Spot Type  Station ID  \
# 0       Cable                             TV        0.0      INV          168
# 1       National Network                  TV       48.0      INV           37
# 2       Cable                             TV       72.0      INV           25
# 3       Cable                             TV      120.0      INV          182
# 4       Cable                             TV        0.0      INV          256
# ...                                ...   ...        ...       ...         ...
# 683352  Cable                             TV        0.0      INV           75
# 683353  Cable                             TV        0.0      INV          161
# 683354  Cable                             TV        0.0      INV          245
# 683355  Cable                             TV        0.0      INV           31
# 683356  Cable                             TV        0.0      INV           26
#
#        Time Aired     DOW      daypart
# 0        00:05:00  Monday   Late Night
# 1        00:05:00  Monday   Late Night
# 2        00:05:00  Monday   Late Night
# 3        00:08:00  Monday   Late Night
# 4        00:10:00  Monday   Late Night
# ...           ...     ...          ...
# 683352   23:50:00  Sunday  Late Fringe
# 683353   23:51:00  Sunday  Late Fringe
# 683354   23:52:00  Sunday  Late Fringe
# 683355   23:53:00  Sunday  Late Fringe
# 683356   23:57:00  Sunday  Late Fringe
#
# [683357 rows x 15 columns]

# %%
dat.describe()
# Out:
#                  GRP    Impressions         Length      Spot Cost  \
# count  683357.000000  503839.000000  683357.000000  683357.000000
# mean        0.003117       3.445929      29.882916      81.776126
# std         0.015593      17.950122       1.320057     108.334736
# min         0.000000       0.000000      15.000000       0.000000
# 25%         0.000000       0.000000      30.000000      48.000000
# 50%         0.000000       0.000000      30.000000      56.000000
# 75%         0.000000       0.000000      30.000000      96.000000
# max         0.864000    1046.400000      30.000000    5208.000000
#
#           Station ID
# count  683357.000000
# mean      199.088294
# std       110.998073
# min         1.000000
# 25%        92.000000
# 50%       219.000000
# 75%       296.000000
# max       379.000000

# %%
dat.dtypes
# Out:
# Access          object
# DMA             object
# Date Aired      object
# Estimate        object
# GRP            float64
# Impressions    float64
# Length           int64
# Market          object
# Media           object
# Spot Cost      float64
# Spot Type       object
# Station ID       int64
# Time Aired      object
# DOW             object
# daypart         object
# dtype: object

# %%
dat["Date Aired"] = pd.to_datetime(dat["Date Aired"], format="%Y-%m-%d")
dat["Time Aired"] = pd.to_datetime(dat["Time Aired"], format="%H:%M:%S").dt.time

# %%
unseen = dat[(dat.Impressions.eq(0.0)) & (dat.GRP.eq(0.0))]
training = dat[dat.GRP > 0.0]

# %%
ax = sns.countplot(x=training["Date Aired"].dt.day_name(), data=dat)

# %%
ax = sns.countplot(x=training["daypart"], data=dat)

# %%
fig, ax = plt.subplots(1, 2)
sns.regplot(x=training["Spot Cost"], y=training["GRP"], data=training, ax=ax[0])
sns.regplot(x=training["Spot Cost"], y=training["Impressions"], data=training, ax=ax[1])

# %%
sns.boxplot(x=training["Market"], y=training["GRP"], data=training, palette="rainbow")

# %%
box = sns.boxplot(x=training["Station ID"], y=training["GRP"], data=training, palette="rainbow")
box.set_xticklabels(box.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Linear Regression

# %%
dat = pd.concat([dat, pd.get_dummies(dat["Estimate"], drop_first=True)], axis=1)
dat = pd.concat([dat, pd.get_dummies(dat["Access"], drop_first=True)], axis=1)
dat = pd.concat([dat, pd.get_dummies(dat["Market"], drop_first=True)], axis=1)
dat = pd.concat([dat, pd.get_dummies(dat["DOW"], drop_first=True)], axis=1)
dat = pd.concat([dat, pd.get_dummies(dat["daypart"], drop_first=True)], axis=1)
dat.columns
# Out:
# Index(['Access', 'DMA', 'Date Aired', 'Estimate', 'GRP', 'Impressions',
#        'Length', 'Market', 'Media', 'Spot Cost', 'Spot Type', 'Station ID',
#        'Time Aired', 'DOW', 'daypart', 'Q219', 'Q319', 'Q419', '15GD', '15PN',
#        '30BP', '30DE', '30DP', '30GD', '30GX', '30PL', '30PM', '30PT', '30SR',
#        '30TN', '30VE', 'SV15', 'DirecTV                       ',
#        'Dish Network                  ', 'National Network              ',
#        'Over-the-top content          ', 'Monday', 'Saturday', 'Sunday',
#        'Thursday', 'Tuesday', 'Wednesday', 'Early Fringe', 'Late Fringe',
#        'Late Night', 'Morning', 'Overnight', 'Primetime'],
#       dtype='object')

# %%
dat = dat.rename(columns=lambda x: x.strip())
dat.columns
# Out:
# Index(['Access', 'DMA', 'Date Aired', 'Estimate', 'GRP', 'Impressions',
#        'Length', 'Market', 'Media', 'Spot Cost', 'Spot Type', 'Station ID',
#        'Time Aired', 'DOW', 'daypart', 'Q219', 'Q319', 'Q419', '15GD', '15PN',
#        '30BP', '30DE', '30DP', '30GD', '30GX', '30PL', '30PM', '30PT', '30SR',
#        '30TN', '30VE', 'SV15', 'DirecTV', 'Dish Network', 'National Network',
#        'Over-the-top content', 'Monday', 'Saturday', 'Sunday', 'Thursday',
#        'Tuesday', 'Wednesday', 'Early Fringe', 'Late Fringe', 'Late Night',
#        'Morning', 'Overnight', 'Primetime'],
#       dtype='object')

# %%
unseen = dat[(dat.Impressions.eq(0.0)) & (dat.GRP.eq(0.0))]
training = dat[dat.GRP > 0.0]

X = training.loc[
    :,
    [
        "Length",
        "Spot Cost",
        "Q219",
        "Q319",
        "Q419",
        "15GD",
        "15PN",
        "30BP",
        "30DE",
        "30DP",
        "30GD",
        "30GX",
        "30PL",
        "30PM",
        "30PT",
        "30SR",
        "30TN",
        "30VE",
        "SV15",
        "DirecTV",
        "Dish Network",
        "National Network",
        "Over-the-top content",
        "Sunday",
        "Thursday",
        "Tuesday",
        "Wednesday",
        "Early Fringe",
        "Late Fringe",
        "Late Night",
        "Morning",
        "Overnight",
        "Primetime",
    ],
]
y = training.loc[:, "GRP"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

lr_preds = lr.predict(X_test)

lr_mse = mean_squared_error(y_test, lr_preds)

# %%
sns.residplot(
    lr_preds.reshape(-1),
    y_test,
    lowess=True,
    line_kws={"color": "red", "lw": 1, "alpha": 1},
)

# %%
residuals = y_test - lr_preds.reshape(-1)
residuals

plt.figure(figsize=(7, 7))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("Normal Q-Q Plot")
# Out:
# Text(0.5, 1.0, 'Normal Q-Q Plot')

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %% [markdown]
# ### XGBoost Regressor

# %%
xgb = XGBRegressor()

xgb.fit(X_train, y_train)
# Out:
# [06:19:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
xgb_preds = xgb.predict(X_test)

xgb_mse = mean_squared_error(y_test, xgb_preds)

# %%
sns.residplot(
    xgb_preds.reshape(-1),
    y_test,
    lowess=True,
    line_kws={"color": "red", "lw": 1, "alpha": 1},
)

# %%
residuals = y_test - xgb_preds.reshape(-1)
residuals

plt.figure(figsize=(7, 7))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("Normal Q-Q Plot")
# Out:
# Text(0.5, 1.0, 'Normal Q-Q Plot')

# %% [markdown]
# ### Outlier Stations

# %%
dat['month'] = pd.DatetimeIndex(dat['Date Aired']).month
dat['month'] = dat['month'].apply(lambda x: calendar.month_name[x])

# %% [markdown]
# #### Outliers by Impressions

# %%
station_averages = dat.groupby(['month', 'Station ID']).mean().reindex(level=1)
monthly_averages = dat.groupby('month').mean().iloc[:, :-1]

# %%
total_averages = station_averages.join(monthly_averages,
                                       on='month', rsuffix='_monthly_averages')

# %% [markdown]
# #### Example 1: Find outlier stations in January using January average for Impressions

# %%
january = total_averages.iloc[total_averages.index.get_level_values('month')=='January']
january = january[january['Impressions'].notnull() & january['Impressions']>0]
january['outliers'] = np.where(january['Impressions'] < january['Impressions'].mean(), False, True)
box = sns.barplot(x=january.index.get_level_values('Station ID'), y=january['Impressions'], 
                  data=january, palette=sns.color_palette(), hue='outliers')
line = box.axhline(january['Impressions'].mean())
box.set_xticklabels(box.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# #### Example 2: Using global average to find outliers in January

# %%
january['global_outliers'] = np.where(january['Impressions'] < dat[dat['Impressions'] > 0 & dat['Impressions'].notnull()]['Impressions'].mean(), 
                                      False, True)
box = sns.barplot(x=january.index.get_level_values('Station ID'), y=january['Impressions'], 
                  data=january, palette=sns.color_palette(), hue='global_outliers')
line = box.axhline(dat[dat['Impressions'] > 0 & dat['Impressions'].notnull()]['Impressions'].mean())
box.set_xticklabels(box.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# #### Example 3: Using GRP

# %%
january['outliers_grp'] = np.where(january['GRP'] < january['GRP'].mean(), False, True)
box = sns.barplot(x=january.index.get_level_values('Station ID'), y=january['GRP'], 
                  data=january, palette=sns.color_palette(), hue='outliers_grp')
line = box.axhline(january['GRP'].mean())
box.set_xticklabels(box.get_xticklabels(), rotation=90)
plt.show()

# %%
january[(january.outliers == True) & (january.outliers_grp == True)]
# Out:
#                          GRP  Impressions  Length   Spot Cost  \
# month   Station ID
# January 184         0.120308   134.450000    30.0   49.230769
#         200         0.221176   272.177778    30.0  588.705882
#         280         0.144000    49.777778    30.0   66.206897
#         340         0.065600    66.514286    30.0  224.000000
#
#                     GRP_monthly_averages  Impressions_monthly_averages  \
# month   Station ID
# January 184                     0.003203                      3.172652
#         200                     0.003203                      3.172652
#         280                     0.003203                      3.172652
#         340                     0.003203                      3.172652
#
#                     Length_monthly_averages  Spot Cost_monthly_averages  \
# month   Station ID
# January 184                            30.0                   10.215887
#         200                            30.0                   10.215887
#         280                            30.0                   10.215887
#         340                            30.0                   10.215887
#
#                     outlier_station_imp  outliers  global_outliers  \
# month   Station ID
# January 184                        True      True             True
#         200                        True      True             True
#         280                        True      True             True
#         340                        True      True             True
#
#                     outliers_grp
# month   Station ID
# January 184                 True
#         200                 True
#         280                 True
#         340                 True
